# %% [markdown]
# <a href="https://colab.research.google.com/github/poornima2635/Data-Handling-And-Visualization/blob/main/Seasonality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv"
data = pd.read_csv(url, parse_dates=['Month'], index_col='Month')

# %%
print(data)
# Out:
#             Sunspots
# Month
# 1749-01-01      58.0
# 1749-02-01      62.6
# 1749-03-01      70.0
# 1749-04-01      55.7
# 1749-05-01      85.0
# ...              ...
# 1983-08-01      71.8
# 1983-09-01      50.3
# 1983-10-01      55.8
# 1983-11-01      33.3
# 1983-12-01      33.4
#
# [2820 rows x 1 columns]

# %%
plt.figure(figsize=(10,6))
plt.plot(data.index, data["Sunspots"], marker="X", linestyle="-")
plt.xlabel("Date")
plt.ylabel("Number of Sunspots")
plt.title("Time Series with Seasonality")
plt.grid(True)
plt.show()
